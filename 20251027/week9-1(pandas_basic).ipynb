# %%
import pandas

# %%
import math

# %%
math.sqrt(3.14)
# Out:
# 1.772004514666935

# %%
pandas.DataFrame([1234,2345,3456,4567])
# Out:
#       0
# 0  1234
# 1  2345
# 2  3456
# 3  4567

# %%
import pandas as pd

# %%
pd.DataFrame([1234,2345,3456,4567])
# Out:
#       0
# 0  1234
# 1  2345
# 2  3456
# 3  4567

# %%
from pandas import DataFrame

# %%
DataFrame([1234,2345,3456,4567])
# Out:
#       0
# 0  1234
# 1  2345
# 2  3456
# 3  4567

# %%
from pandas import DataFrame as DF

# %%
DF([1234,2345,3456,4567])
# Out:
#       0
# 0  1234
# 1  2345
# 2  3456
# 3  4567

# %%
df = pd.DataFrame([
    ['Kim', 22, '010-0000-1234', 'M'],
    ['Na', 26, '010-0000-5678', 'M'],
    ['Park', 23, '010-1234-1234', 'F'],
    ['Lee', 24, '010-5678-5678', 'F']
], columns=['Name', 'Age', 'Phone', 'Gender'])

# %%
df
# Out:
#    Name  Age          Phone Gender
# 0   Kim   22  010-0000-1234      M
# 1    Na   26  010-0000-5678      M
# 2  Park   23  010-1234-1234      F
# 3   Lee   24  010-5678-5678      F

# %%
df.shape
# Out:
# (4, 4)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Phone', 'Gender'], dtype='object')

# %%
len(df.columns)
# Out:
# 4

# %%
df.columns[0]
# Out:
# 'Name'

# %%
# loc[] -> 라벨(index) 기반
df.loc[0]
# Out:
# Name                Kim
# Age                  22
# Phone     010-0000-1234
# Gender                M
# Name: 0, dtype: object

# %%
#iloc[] -> 실제 위치 기반
df.iloc[0]
# Out:
# Name                Kim
# Age                  22
# Phone     010-0000-1234
# Gender                M
# Name: 0, dtype: object

# %%
df.iloc[0]['Age']
# Out:
# np.int64(22)

# %%
df['Age']
# Out:
# 0    22
# 1    26
# 2    23
# 3    24
# Name: Age, dtype: int64

# %%
df['Age'].sum() # Age 컬럼의 합계
# Out:
# np.int64(95)

# %%
df['Age'].mean() # Age 컬럼의 평균
# Out:
# np.float64(23.75)

# %%
df['Age'].median() # Age 컬럼의 중앙값
# Out:
# 23.5

# %%
df['Age'].var() # Age 컬럼의 분산
# Out:
# 2.9166666666666665

# %%
df['Age'].std() # Age 컬럼의 표준편차
# Out:
# 1.707825127659933

# %%
df['Age'].max() # Age 컬럼의 최대값
# Out:
# 26

# %%
df['Age'].min() # Age 컬럼의 최소값
# Out:
# 22

# %%
df
# Out:
#    Name  Age          Phone Gender
# 0   Kim   22  010-0000-1234      M
# 1    Na   26  010-0000-5678      M
# 2  Park   23  010-1234-1234      F
# 3   Lee   24  010-5678-5678      F

# %%
df['Gender'].value_counts() # Gender 컬럼의 빈도수
# Out:
# Gender
# M    2
# F    2
# Name: count, dtype: int64

# %%
df[df['Gender'] == 'M']
# Out:
#   Name  Age          Phone Gender
# 0  Kim   22  010-0000-1234      M
# 1   Na   26  010-0000-5678      M

# %%
df[df['Gender'] == 'F']
# Out:
#    Name  Age          Phone Gender
# 2  Park   23  010-1234-1234      F
# 3   Lee   24  010-5678-5678      F

# %%
df[df['Gender'] == 'M']['Age'].mean()
# Out:
# np.float64(24.0)

# %%
for g in ['M', 'F'] :
    print (g, df[df['Gender'] == g]['Age'].mean())
# Out:
# M 24.0
# F 23.5

# %%
df['Gender'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
for g in df['Gender'].unique() :
    print (g, df[df['Gender'] == g]['Age'].mean())
# Out:
# M 24.0
# F 23.5

# %%
list(df.groupby('Gender'))
# Out:
# [('F',
#      Name  Age          Phone Gender
#   2  Park   23  010-1234-1234      F
#   3   Lee   24  010-5678-5678      F),
#  ('M',
#     Name  Age          Phone Gender
#   0  Kim   22  010-0000-1234      M
#   1   Na   26  010-0000-5678      M)]

# %%
GAmean = df.groupby('Gender')['Age'].mean()

# %%
type(GAmean)
# Out:
# pandas.core.series.Series

# %%
pd.DataFrame(['Kim','Na','Park','Lee'], columns=['Last Name'], index=['1','2','3','4',])
# Out:
#   Last Name
# 1       Kim
# 2        Na
# 3      Park
# 4       Lee
